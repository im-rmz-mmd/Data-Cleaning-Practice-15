# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('pixar.csv')
df
# Out:
#                    film       budget  box_office_us_canada  box_office_other  \
# 0             Toy Story   30000000.0             223225679         171210907
# 1          A Bug's Life  120000000.0             162798565         200460294
# 2           Toy Story 2   90000000.0             245852179         265506097
# 3        Monsters, Inc.  115000000.0             255873250         272900000
# 4          Finding Nemo   94000000.0             339714978         531300000
# 5       The Incredibles   92000000.0             261441092         370001000
# 6                  Cars  120000000.0             244082982         217900167
# 7           Ratatouille  150000000.0             206445654         417280431
# 8                WALL-E  180000000.0             223808164         297503696
# 9                    Up  175000000.0             293004164         442094918
# 10          Toy Story 3  200000000.0             415004880         651964823
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                    film       budget  box_office_us_canada  box_office_other  \
# 0             Toy Story   30000000.0             223225679         171210907
# 1          A Bug's Life  120000000.0             162798565         200460294
# 2           Toy Story 2   90000000.0             245852179         265506097
# 3        Monsters, Inc.  115000000.0             255873250         272900000
# 4          Finding Nemo   94000000.0             339714978         531300000
# 5       The Incredibles   92000000.0             261441092         370001000
# 6                  Cars  120000000.0             244082982         217900167
# 7           Ratatouille  150000000.0             206445654         417280431
# 8                WALL-E  180000000.0             223808164         297503696
# 9                    Up  175000000.0             293004164         442094918
# 10          Toy Story 3  200000000.0             415004880         651964823
# ...

# %%
df = df.rename(columns = {'film' : 'Animation', 'budget' : 'Budget',
                'box_office_us_canada' : 'US Box Office', 'box_office_other' : 'World Box Office',
                'box_office_worldwide' : 'Total Box Office', 'rotten_tomatoes_score' : 'Rotten Score',
                'rotten_tomatoes_counts' : 'Rotten Counts', 'metacritic_score' : 'Metacritic Score',
                'metacritic_counts' : 'Metacritic Counts', 'cinema_score' : 'Cinema Score',
                'imdb_score' : 'Imdb Score', 'imdb_counts' : 'Imdb Counts'})
df
# Out:
#               Animation       Budget  US Box Office  World Box Office  \
# 0             Toy Story   30000000.0      223225679         171210907
# 1          A Bug's Life  120000000.0      162798565         200460294
# 2           Toy Story 2   90000000.0      245852179         265506097
# 3        Monsters, Inc.  115000000.0      255873250         272900000
# 4          Finding Nemo   94000000.0      339714978         531300000
# 5       The Incredibles   92000000.0      261441092         370001000
# 6                  Cars  120000000.0      244082982         217900167
# 7           Ratatouille  150000000.0      206445654         417280431
# 8                WALL-E  180000000.0      223808164         297503696
# 9                    Up  175000000.0      293004164         442094918
# 10          Toy Story 3  200000000.0      415004880         651964823
# 11               Cars 2  200000000.0      191452396         368400000
# ...

# %%
df.at[23, 'Budget'] = 165000000
df
# Out:
#               Animation       Budget  US Box Office  World Box Office  \
# 0             Toy Story   30000000.0      223225679         171210907
# 1          A Bug's Life  120000000.0      162798565         200460294
# 2           Toy Story 2   90000000.0      245852179         265506097
# 3        Monsters, Inc.  115000000.0      255873250         272900000
# 4          Finding Nemo   94000000.0      339714978         531300000
# 5       The Incredibles   92000000.0      261441092         370001000
# 6                  Cars  120000000.0      244082982         217900167
# 7           Ratatouille  150000000.0      206445654         417280431
# 8                WALL-E  180000000.0      223808164         297503696
# 9                    Up  175000000.0      293004164         442094918
# 10          Toy Story 3  200000000.0      415004880         651964823
# 11               Cars 2  200000000.0      191452396         368400000
# ...

# %%
df.at[(22, 23, 24), 'Cinema Score'] = 'A'
df
# Out:
#               Animation       Budget  US Box Office  World Box Office  \
# 0             Toy Story   30000000.0      223225679         171210907
# 1          A Bug's Life  120000000.0      162798565         200460294
# 2           Toy Story 2   90000000.0      245852179         265506097
# 3        Monsters, Inc.  115000000.0      255873250         272900000
# 4          Finding Nemo   94000000.0      339714978         531300000
# 5       The Incredibles   92000000.0      261441092         370001000
# 6                  Cars  120000000.0      244082982         217900167
# 7           Ratatouille  150000000.0      206445654         417280431
# 8                WALL-E  180000000.0      223808164         297503696
# 9                    Up  175000000.0      293004164         442094918
# 10          Toy Story 3  200000000.0      415004880         651964823
# 11               Cars 2  200000000.0      191452396         368400000
# ...

# %%
df['Budget'] = df['Budget'].astype('int')
df.dtypes
# Out:
# Animation             object
# Budget                 int64
# US Box Office          int64
# World Box Office       int64
# Total Box Office       int64
# Rotten Score           int64
# Rotten Counts          int64
# Metacritic Score       int64
# Metacritic Counts      int64
# Cinema Score          object
# Imdb Score           float64
# Imdb Counts            int64
# dtype: object

# %%
df
# Out:
#               Animation     Budget  US Box Office  World Box Office  \
# 0             Toy Story   30000000      223225679         171210907
# 1          A Bug's Life  120000000      162798565         200460294
# 2           Toy Story 2   90000000      245852179         265506097
# 3        Monsters, Inc.  115000000      255873250         272900000
# 4          Finding Nemo   94000000      339714978         531300000
# 5       The Incredibles   92000000      261441092         370001000
# 6                  Cars  120000000      244082982         217900167
# 7           Ratatouille  150000000      206445654         417280431
# 8                WALL-E  180000000      223808164         297503696
# 9                    Up  175000000      293004164         442094918
# 10          Toy Story 3  200000000      415004880         651964823
# 11               Cars 2  200000000      191452396         368400000
# 12                Brave  185000000      237283207         301700000
# ...

# %%
df = df.to_excel('Cleaned Pixar.xlsx', index = False)
